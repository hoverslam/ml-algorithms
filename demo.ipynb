# %%
import numpy as np
import matplotlib.pyplot as plt

from neural_network.perceptron import MLP
from utils.datasets import generate_data, split_data

# %%
X, y = generate_data(100, type="regression", n_features=10)
X_train, X_test, y_train, y_test = split_data(X, y)

# %%
model = MLP(X.shape[0], (30,), lr=1e-2)
history = model.fit(X_train, y_train, 100)
plt.plot(history["epoch"], history["loss"])
# Out:
# Loss=171.7407: 100%|██████████| 100/100 [01:28<00:00,  1.13it/s]
